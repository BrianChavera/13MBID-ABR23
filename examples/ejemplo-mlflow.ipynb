# %%
import mlflow

from sklearn.model_selection import train_test_split
from sklearn.datasets import load_diabetes
from sklearn.ensemble import RandomForestRegressor

# %%
# Se hace la lectura del dataset de prueba

db = load_diabetes()
X_train, X_test, y_train, y_test = train_test_split(db.data, db.target)

# %%
# Opción básica
mlflow.autolog()

# Create and train models.
rf = RandomForestRegressor(n_estimators=100, max_depth=6, max_features=3)
rf.fit(X_train, y_train)

# Use the model to make predictions on the test dataset.
predictions = rf.predict(X_test)
# Out:
# 2023/12/12 14:02:44 WARNING mlflow.utils.autologging_utils: You are using an unsupported version of sklearn. If you encounter errors during autologging, try upgrading / downgrading sklearn to a supported version, or try upgrading MLflow.
# 2023/12/12 14:02:45 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2023/12/12 14:02:45 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '566c867be3d44df0989cd315ed7a2e6e', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2023/12/12 14:02:51 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "c:\Users\Home\.conda\envs\EntornoVIU\Lib\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils."

# %%
# Create and train models.
rf2 = RandomForestRegressor(n_estimators=50, max_depth=3, max_features=5)
rf2.fit(X_train, y_train)

# Use the model to make predictions on the test dataset.
predictions2 = rf2.predict(X_test)
# Out:
# 2023/12/12 14:02:52 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'eee5d18396d34c2d94c477af1d796e06', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow

# %%
# Se puede hacer una experimentación nominal

mlflow.set_experiment(experiment_name="prueba-template")
mlflow.autolog()
# Out:
# 2023/12/12 14:02:59 WARNING mlflow.utils.autologging_utils: You are using an unsupported version of sklearn. If you encounter errors during autologging, try upgrading / downgrading sklearn to a supported version, or try upgrading MLflow.
# 2023/12/12 14:02:59 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.

# %%
# Se puede otorgar un nombre a la ejecución

with mlflow.start_run(run_name='Randrom Forest'):
    # Create and train models.
    rf3 = RandomForestRegressor(n_estimators=100, max_depth=6, max_features=3)
    rf3.fit(X_train, y_train)

    # Use the model to make predictions on the test dataset.
    predictions3 = rf3.predict(X_test)

# %%
# Se puede dar otro nombre y variar representatividad

with mlflow.start_run(run_name='Otra tecnica'):
    # Create and train models.
    rf = RandomForestRegressor(n_estimators=100, max_depth=6, max_features=3)
    rf.fit(X_train, y_train)

    # Use the model to make predictions on the test dataset.
    predictions = rf.predict(X_test)

# %%
# !mlflow ui
